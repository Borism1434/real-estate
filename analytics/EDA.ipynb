# %%
from dotenv import load_dotenv
import os

# Point explicitly to your .env file
load_dotenv(dotenv_path=os.path.expanduser("~/Documents/real-estate/.env"))

print(os.getenv("DB_NAME"))  # should now show 'real_estate'
# Out:
# real_estate

# %%
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys, os
project_root = os.path.abspath("..")  # Or adjust accordingly
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from etl.loader import run_query


df = run_query("SELECT * FROM int.target_strategy")
df = df.iloc[:,:]

# %%
from summarytools import dfSummary

# Separate columns by type
numeric_cols = df.select_dtypes(include='number').columns.tolist()
text_cols = df.select_dtypes(include='object').columns.tolist()

# Reorder DataFrame columns: numeric first, then text
ordered_df = df[numeric_cols + text_cols]

# Generate summary in plain text (default behavior)
summary = dfSummary(df)
summary
# Out:
# <style type="text/css">
# #T_1ab17 thead>tr>th {
#   text-align: left;
# }
# ...
